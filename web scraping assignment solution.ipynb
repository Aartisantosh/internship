# %% [markdown]
#  web scraping assignment

# %% [markdown]
# Q1 Write a python program to display all the header tags from wikipedia.org and make data frame.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
page=requests.get('https://en.wikipedia.org/wiki/Main_Page')
page
bs = BeautifulSoup(page.content, "html.parser")
header_tags = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
header_texts=[tag.get_text() for tag in header_tags]
df = pd.DataFrame(header_texts, columns=["Header"])
df
# Out:
#                           Header
# 0                      Main Page
# 1           Welcome to Wikipedia
# 2  From today's featured article
# 3               Did you know ...
# 4                    In the news
# 5                    On this day
# 6       Today's featured picture
# 7       Other areas of Wikipedia
# 8    Wikipedia's sister projects
# 9            Wikipedia languages

# %% [markdown]
#  Q 2.Write s python program to display list of respected former presidents of India(i.e. Name , Term ofoffice)
# from https://presidentofindia.nic.in/former-presidents.htm and make data frame.

# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd
pres = requests.get('https://presidentofindia.nic.in/former-presidents')

pres
soup = BeautifulSoup(pres.content)
soup
president_name = [] 
for i in in_pres.find_all('div', class_="desc-sec"):
    president_name.append(i.text.replace('\n',''))
    
president_name
df_pres = pd.DataFrame({'Name of President and Term of office':president_name })
df_pres
pat = '(\D+)'
all_names = df_pres['Name of President and Term of office'].str.extract(pat,expand=False)
all_names

df1 = pd.DataFrame({'Name of President': all_names,
                     'Term of Office': ['25th July, 2017 - 25th July 2022','25th July 2012 - 25th July 2017','25th July 2007 - 25th July 2012','July 2002 - 25th July 2007',' 25 July, 1997 - 25 July 2002','25 July, 1992 - 25 July, 1997','25 July, 1987 - 25 July, 1992','25 July, 1982 - 25 July, 1987',' 25 July, 1977 - 25 July, 1982','24 August, 1974 - 11 February, 1977','24 August, 1969 - 24 August, 1974',' 13 May, 1967 - 03 May, 1969','13 May, 1962 - 13 May , 1967','26 January, 1950 - 13 May, 1962']})
df1
# Out:
#                Name of President                       Term of Office
# 0           Shri Ram Nath Kovind     25th July, 2017 - 25th July 2022
# 1          Shri Pranab Mukherjee      25th July 2012 - 25th July 2017
# 2   Smt Pratibha Devisingh Patil      25th July 2007 - 25th July 2012
# 3         DR. A.P.J. Abdul Kalam           July 2002 - 25th July 2007
# 4           Shri K. R. Narayanan         25 July, 1997 - 25 July 2002
# 5        Dr Shankar Dayal Sharma        25 July, 1992 - 25 July, 1997
# 6            Shri R Venkataraman        25 July, 1987 - 25 July, 1992
# 7               Giani Zail Singh        25 July, 1982 - 25 July, 1987
# 8      Shri Neelam Sanjiva Reddy        25 July, 1977 - 25 July, 1982
# 9       Dr. Fakhruddin Ali Ahmed  24 August, 1974 - 11 February, 1977
# 10  Shri Varahagiri Venkata Giri    24 August, 1969 - 24 August, 1974
# 11              Dr. Zakir Husain          13 May, 1967 - 03 May, 1969
# 12  Dr. Sarvepalli Radhakrishnan         13 May, 1962 - 13 May , 1967
# 13           Dr. Rajendra Prasad      26 January, 1950 - 13 May, 1962

# %% [markdown]
# 3) Write a python program to scrape cricket rankings from icc-cricket.com.You have to scrape and make data frame
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team  and rating.
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
#) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.icc-cricket.com/rankings/team-rankings/mens/odi"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
#print(soup)

teams = []
for row in soup.find_all("div", class_="si-table-data-wrap"):
    team = row.find("h3",class_="si-team-name").text.strip()
    
matches = []    
for row in soup.find_all("div", class_="si-table-data si-matches"):    
    match = row.find("span", class_="si-text").text.strip()
                      
points = []                     
for row in soup.find_all("div",class_="si-table-data si-pts"):
    point = row.find("span", class_="si-text").text.strip()
                      
ratings = []   
for row in soup.find_all("div",class_="si-table-data si-rating" ):                     
    rating =row.find("span",class_="si-text").text.strip()
    
    teams.append(team)
    matches.append(match)
    points.append(point)
    ratings.append(rating)

    
data = {"Team": teams, "Matches": matches, "Points": points, "Rating": ratings}
df = pd.DataFrame(data)
print("Top 10 ODI Teams in Men's Cricket:")
print(df)
# Out:
# Top 10 ODI Teams in Men's Cricket:
# Empty DataFrame
# Columns: [Team, Matches, Points, Rating]
# Index: []

# %%
# b) Top 10 ODI Batsmen along with the records of their team  and rating

import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.icc-cricket.com/rankings/team-rankings/mens/odi"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
#print(soup)

# %% [markdown]
# 4) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
#a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
5) Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world and
make data frame
i) Headline
ii) Time
iii) News Link

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


page=requests.get("https://www.cnbc.com/world/?region=world")
# page
soup = BeautifulSoup(page.content, "html.parser")
# print(soup)

headLines = []
newsLinks = []
times = []
for article in soup.find_all("div", class_="LatestNews-container"):
    headline = article.find("a", class_="LatestNews-headline").text.strip()
    time = article.find("time", class_="LatestNews-timestamp").text.strip()
    link = article.find("a", href=True)["href"]
    
    headLines.append(headline)
    times.append(time)
    newsLinks.append(link)
    
print(len(headLines),len( times),len( newsLinks))   

df = pd.DataFrame({
        'HeadLine': headLines,
        'Time': times,
        'NewsLink': newsLinks
    })    
    
print(df)
# Out:
# 30 30 30
#                                              HeadLine              Time  \
# 0   Here's why Buffett calls airline stocks hazard...         4 Min Ago
# 1   Wall Street made bold calls on 4 of our stocks...      17 Hours Ago
# 2   The Iowa caucuses are on Monday — here's what ...      18 Hours Ago
# 3   You can get fit without breaking the bank—and ...      19 Hours Ago
# 4   'Taiwan is China's Taiwan': Beijing reacts to ...      21 Hours Ago
# 5   This year, I’m doing less—it's a ‘great idea f...      21 Hours Ago
# 6   The 3 most important things we're watching in ...      21 Hours Ago
# 7   38-year-old went from $218,000 in debt to rest...      21 Hours Ago
# 8   The 5 levels of financial freedom, according t...      22 Hours Ago
# 9   In 1997, Jeff Bezos revealed why books were th...      22 Hours Ago
# 10  Market has cooled to start 2024, but it's stil...      22 Hours Ago
# 11  Investing in hobbies can be money well spent —...      23 Hours Ago
# 12  How the Rubik's Cube captures hearts and marke...      23 Hours Ago
# 13  Bitcoin ETFs could open floodgates to $30 tril...      23 Hours Ago
# 14  China skeptic Lai Ching-te wins Taiwan's presi...      24 Hours Ago
# 15  Investor shares his top 5 picks to play an unc...  January 13, 2024
# 16  Goldman's top stocks for 2024, including this ...  January 13, 2024
# 17  Kansas City Chiefs CEO says audience grew afte...  January 12, 2024
# 18  Jim Cramer compares NFL playoff teams to stock...  January 12, 2024
# 19             Cramer's Lightning Round: No to Altria  January 12, 2024
# 20  Cramer's week ahead: Keep an eye on banks' ear...  January 12, 2024
# 21  Microsoft tops Apple as world's most valuable ...  January 12, 2024
# 22  Flight cancellations pile up as weather, 737 M...  January 12, 2024
# 23  Bitcoin’s post-ETF launch decline may continue...  January 12, 2024
# 24  Investors selling Wells Fargo stock after earn...  January 12, 2024
# 25  Trump ordered to pay New York Times, 3 reporte...  January 12, 2024
# 26  Corona-maker AB InBev to have first beer spons...  January 12, 2024
# 27  Jim Cramer says this new Meta product could be...  January 12, 2024
# 28  Tanker companies halt traffic toward Red Sea a...  January 12, 2024
# 29  There's a new era coming for dividend stocks, ...  January 12, 2024
#
#                                              NewsLink
# 0                                               /pro/
# 1                                     /investingclub/
# 2   https://www.cnbc.com/2024/01/13/the-iowa-caucu...
# 3   https://www.cnbc.com/2024/01/13/you-can-get-fi...
# 4   https://www.cnbc.com/2024/01/13/china-reacts-t...
# 5   https://www.cnbc.com/2024/01/13/this-new-year-...
# 6                                     /investingclub/
# 7   https://www.cnbc.com/2024/01/13/how-orlando-re...
# 8   https://www.cnbc.com/2024/01/13/5-levels-of-fi...
# 9   https://www.cnbc.com/2024/01/13/in-1997-jeff-b...
# 10                                              /pro/
# 11  https://www.cnbc.com/2024/01/13/investing-in-h...
# 12  https://www.cnbc.com/2024/01/13/rubiks-cube-sp...
# 13  https://www.cnbc.com/2024/01/13/the-30-trillio...
# 14  https://www.cnbc.com/2024/01/13/taiwan-2024-el...
# 15                                              /pro/
# 16                                              /pro/
# 17  https://www.cnbc.com/2024/01/12/kansas-city-ch...
# 18  https://www.cnbc.com/2024/01/12/jim-cramer-com...
# 19  https://www.cnbc.com/2024/01/12/cramers-lightn...
# 20  https://www.cnbc.com/2024/01/12/cramers-week-a...
# 21  https://www.cnbc.com/2024/01/12/microsoft-tops...
# 22  https://www.cnbc.com/2024/01/12/flights-cancel...
# 23                                              /pro/
# 24                                    /investingclub/
# 25  https://www.cnbc.com/2024/01/12/trump-ordered-...
# 26  https://www.cnbc.com/2024/01/12/corona-maker-a...
# 27                                    /investingclub/
# 28  https://www.cnbc.com/2024/01/12/tanker-compani...
# 29                                              /pro/

# %% [markdown]
# 6) Write a python program to scrape the details of most downloaded articles from AI in last 90
# days.https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles
# Scrape below mentioned details and make data frame
# i) Paper Title
# ii) Authors
# iii) Published Date
# iv) Paper URL

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


url = "https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles"
response = requests.get(url)
response
soup = BeautifulSoup(response.content, "html.parser")
soup
titles = []
authors = []
dates=[]
urls=[]
for article in soup.find_all("li", class_="sc-9zxyh7-1 sc-9zxyh7-2 kOEIEO hvoVxs"):
    title = article.find("h2",class_="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg").text.strip()
    author = article.find("span", class_="sc-1w3fpd7-0 dnCnAO").text.strip()
    date = article.find("span", class_="sc-1thf9ly-2 dvggWt").text.strip()
    url = article.find("a",href=True)["href"]
    
    titles.append(title)
    authors.append(author)
    dates.append(date)
    urls.append(url)
print(len(titles),len(authors),len(dates),len(urls))
df=pd.DataFrame({'Paper Title':titles,'Authors':authors,'Published Date':date,'Paper URL':urls})
df
# Out:
# 24 24 24 24
#                                           Paper Title  \
# 0                                    Reward is enough
# 1   Explanation in artificial intelligence: Insigh...
# 2              Creativity and artificial intelligence
# 3   Conflict-based search for optimal multi-agent ...
# 4   Knowledge graphs as tools for explainable mach...
# 5   Law and logic: A review from an argumentation ...
# 6   Between MDPs and semi-MDPs: A framework for te...
# 7   Explaining individual predictions when feature...
# 8       Multiple object tracking: A literature review
# 9   A survey of inverse reinforcement learning: Ch...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11  Explainable AI tools for legal reasoning about...
# 12            Hard choices in artificial intelligence
# 13  Assessing the communication gap between AI mod...
# 14  Explaining black-box classifiers using post-ho...
# 15  The Hanabi challenge: A new frontier for AI re...
# 16              Wrappers for feature subset selection
# 17  Artificial cognition for social human–robot in...
# 18  A review of possible effects of cognitive bias...
# 19  The multifaceted impact of Ada Lovelace in the...
# 20  Robot ethics: Mapping the issues for a mechani...
# 21          Reward (Mis)design for autonomous driving
# 22  Planning and acting in partially observable st...
# 23  What do we want from Explainable Artificial In...
#
#                                               Authors Published Date  \
# 0   David Silver, Satinder Singh, Doina Precup, Ri...      July 2021
# 1                                          Tim Miller      July 2021
# 2                                   Margaret A. Boden      July 2021
# 3   Guni Sharon, Roni Stern, Ariel Felner, Nathan ...      July 2021
# 4                      Ilaria Tiddi, Stefan Schlobach      July 2021
# 5                      Henry Prakken, Giovanni Sartor      July 2021
# 6     Richard S. Sutton, Doina Precup, Satinder Singh      July 2021
# 7           Kjersti Aas, Martin Jullum, Anders Løland      July 2021
# 8                Wenhan Luo, Junliang Xing and 4 more      July 2021
# 9                       Saurabh Arora, Prashant Doshi      July 2021
# 10  Jasper van der Waa, Elisabeth Nieuwburg, Anita...      July 2021
# 11  Joe Collenette, Katie Atkinson, Trevor Bench-C...      July 2021
# 12   Roel Dobbe, Thomas Krendl Gilbert, Yonatan Mintz      July 2021
# 13  Oskar Wysocki, Jessica Katharine Davies and 5 ...      July 2021
# 14  Eoin M. Kenny, Courtney Ford, Molly Quinn, Mar...      July 2021
# 15          Nolan Bard, Jakob N. Foerster and 13 more      July 2021
# 16                         Ron Kohavi, George H. John      July 2021
# 17      Séverin Lemaignan, Mathieu Warnier and 3 more      July 2021
# 18    Tomáš Kliegr, Štěpán Bahník, Johannes Fürnkranz      July 2021
# 19                             Luigia Carlucci Aiello      July 2021
# 20             Patrick Lin, Keith Abney, George Bekey      July 2021
# 21     W. Bradley Knox, Alessandro Allievi and 3 more      July 2021
# 22  Leslie Pack Kaelbling, Michael L. Littman, Ant...      July 2021
# 23             Markus Langer, Daniel Oster and 6 more      July 2021
#
#                                             Paper URL
# 0   https://www.sciencedirect.com/science/article/...
# 1   https://www.sciencedirect.com/science/article/...
# 2   https://www.sciencedirect.com/science/article/...
# 3   https://www.sciencedirect.com/science/article/...
# 4   https://www.sciencedirect.com/science/article/...
# 5   https://www.sciencedirect.com/science/article/...
# 6   https://www.sciencedirect.com/science/article/...
# 7   https://www.sciencedirect.com/science/article/...
# 8   https://www.sciencedirect.com/science/article/...
# 9   https://www.sciencedirect.com/science/article/...
# 10  https://www.sciencedirect.com/science/article/...
# 11  https://www.sciencedirect.com/science/article/...
# 12  https://www.sciencedirect.com/science/article/...
# 13  https://www.sciencedirect.com/science/article/...
# 14  https://www.sciencedirect.com/science/article/...
# 15  https://www.sciencedirect.com/science/article/...
# 16  https://www.sciencedirect.com/science/article/...
# 17  https://www.sciencedirect.com/science/article/...
# 18  https://www.sciencedirect.com/science/article/...
# 19  https://www.sciencedirect.com/science/article/...
# 20  https://www.sciencedirect.com/science/article/...
# 21  https://www.sciencedirect.com/science/article/...
# 22  https://www.sciencedirect.com/science/article/...
# 23  https://www.sciencedirect.com/science/article/...

# %% [markdown]
# 7) Write a python program to scrape mentioned details from dineout.co.in and make data frame
# i) Restaurant name
# ii) Cuisine
# iii) Location
# iv) Ratings
# v) Image URL

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://www.dineout.co.in/delhi-restaurants'

response = requests.get(url)
response
soup = BeautifulSoup(response.content, 'html.parser')
soup

titles=[]
for detail in soup.find_all('div',class_="restnt-info cursor"):
    titles .append(detail.text)
titles 

location=[]
for detail in soup.find_all('div',class_="restnt-loc ellipsis"):
     location.append(detail.text)
location 

images=[]
for detail in soup.find_all("img",class_="no-img"):
    images.append(detail['data-src'])

images

ratings=[]
for detail in soup.find_all("div",class_="restnt-rating rating-4"):
    ratings.append(detail.text)

ratings

cuisines = []
for detail in soup.find_all("span",class_="double-line-ellipsis"):
    cuisine = detail.find('a')
    cuisines.append(cuisine.text)
    cuisines
    
print(len(titles),len(location),len(ratings),len(images),len(cuisines))

df=pd.DataFrame({'Restaurant Name': restaurantNames ,
                 'Location':locations ,
                 'Ratings':ratings,
                 'Image URL': images,'Cuisines':cuisines}) 
df
# Out:
# 21 21 21 21 21
#                     Restaurant Name  \
# 0                     The G.T. Road
# 1                Kwality Restaurant
# 2               My Bar Headquarters
# 3                            Sandoz
# 4               Unplugged Courtyard
# 5                         Oh My God
# 6                     My Bar Square
# 7                           Tamasha
# 8      Yeti - The Himalayan Kitchen
# 9                           Berco's
# 10          Ce La Vie Kitchen & Bar
# 11             Connaught Club House
# 12                 Ministry Of Beer
# 13                      Dasaprakash
# 14                       Farzi Cafe
# 15       Somewhere Restaurant & Bar
# 16               The Imperial Spice
# 17                    Pind Balluchi
# 18             Connaught Club House
# 19  Ardor 2.1 Restaurant and Lounge
# 20                   Openhouse Cafe
#
#                                              Location Ratings  \
# 0          [M-Block,, Connaught Place, Central Delhi]     4.3
# 1   [Regal Cinema Complex,, Connaught Place, Centr...     4.4
# 2                    [Connaught Place, Central Delhi]       4
# 3                    [Connaught Place, Central Delhi]       4
# 4                    [Connaught Place, Central Delhi]       4
# 5          [F-Block,, Connaught Place, Central Delhi]       4
# 6                    [Connaught Place, Central Delhi]     3.9
# 7                    [Connaught Place, Central Delhi]     4.2
# 8    [The Colonnade,, Connaught Place, Central Delhi]     4.3
# 9                    [Connaught Place, Central Delhi]     4.3
# 10                   [Connaught Place, Central Delhi]     4.2
# 11                           [Janpath, Central Delhi]     4.4
# 12         [M-Block,, Connaught Place, Central Delhi]       4
# 13                   [Connaught Place, Central Delhi]     4.2
# 14                   [Connaught Place, Central Delhi]     4.1
# 15                   [Connaught Place, Central Delhi]     4.1
# 16         [M-Block,, Connaught Place, Central Delhi]     4.4
# 17  [Regal Cinema Complex,, Connaught Place, Centr...     4.1
# 18                   [Connaught Place, Central Delhi]     4.2
# 19                   [Connaught Place, Central Delhi]     4.1
# 20                   [Connaught Place, Central Delhi]     4.1
#
#                                             Image URL       Cuisines
# 0   https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 1   https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 2   https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 3   https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 4   https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 5   https://im1.dineout.co.in/images/uploads/resta...    Continental
# 6   https://im1.dineout.co.in/images/uploads/resta...    Finger Food
# 7   https://im1.dineout.co.in/images/uploads/resta...    Continental
# 8   https://im1.dineout.co.in/images/uploads/resta...        Tibetan
# 9   https://im1.dineout.co.in/images/uploads/resta...        Chinese
# 10  https://im1.dineout.co.in/images/uploads/resta...    Continental
# 11  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 12  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 13  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 14  https://im1.dineout.co.in/images/uploads/resta...  Modern Indian
# 15  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 16  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 17  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 18  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 19  https://im1.dineout.co.in/images/uploads/resta...   North Indian
# 20  https://im1.dineout.co.in/images/uploads/resta...   North Indian
